# %% [markdown]
# # User Review Corpus from RPG Games Published in Steam
#
# ## Scraping Data

# %%
from bs4 import BeautifulSoup
import requests

def get_reviews(appid, params={'json':1}, lang="english", filter="toprated"):
        url=f'https://store.steampowered.com/appreviews/{appid}'
        response = requests.get(url=url, params=params)
        return response.json()
    
def get_n_reviews(appid, n):
    reviews = []
    cursor = '*'
    params = {
            'json' : 1,
            'filter' : 'recent',
            'language' : 'english',
            'day_range' : 28,
            'review_type' : 'all',
            'purchase_type' : 'steam'
            }

    while n > 0:
        params['cursor'] = cursor.encode()
        params['num_per_page'] = 100
        n -= 1

        response = get_reviews(str(appid))
        cursor = response['cursor']
        reviews += response['reviews']

        if len(response['reviews']) < 100: break

    return reviews

n=100
reviews = get_n_reviews(1086940,100)

# %% [markdown]
# ## Text Vectorization Process

# %%
import re, string, unicodedata
 
def remove_non_ascii(text):
    return re.sub(r'[^\x00-\x7F]+', '', text)

documents = []

def tokenize(s):
    s = remove_non_ascii(s)
    regex = re.compile('[%s]' % re.escape(string.punctuation))
    res = regex.sub('', s)
    # res = res.split()
    return res

for review in reviews:
    # clean_review = tokenize(review['review'])
    # for clean in clean_review:
        # documents.append(clean)
    clean = remove_non_ascii(review['review'])
    documents.append(tokenize(clean))

documents
# Out:
# ['Its DnD for people with no friends',
#  'Karlach',
#  'Im not any fancy reviewer however I am a gamer and consumer like the rest of you kindly requesting you offer a few minutes to hear what I have to share\nLet me start being brief Larian Studios has blown me away\n\nFor some context of who I am and where I come from I have loved the divinity games for a few years now and was hyped for them being announced to make the successor to Balldurs Gate I  II \nI am a also a Gamemaster and have been for Dungeons  Dragons nearly fourteen years now Ive been in the DnD sphere of games and RPGs since the beginnings of 2nd Edition when I was really young I have experienced each system across the board numerous titles accompanying the array of editions published \n\nTo speak of BG III itself What Larian did here not only blew away my expectations as a DD experience but honored many of the greatest markers of DD and RPG and CRPG history that can be found as DD has evolved over its many years What Larian has done is created the perfect gateway into Baldurs gate and older classics with the fervor and easy accessibility of 5th edition DD \n\nBaldurs Gate III has done the impossible this is the perfect place to begin if you never played DD and would like to feel what its like or if you just cannot access a DD group and still would like to play BG III utilizes the best parts of the game system and highlights them with an exemplary immersive experience that showcases many old classics that came before in the same curated heart and care in their creation years ago\nEven still it rests at a comfortable price with an innumerable amounts of replayability at your fingertips with one price tag No microtransactions no subscriptions no catches BG III was made for you and I both fans and gamers each A true testaments to the games that came before and were adored for the respect and care for not only the game but those who are playing their game \n\nLarian Studios have been folk I have chosen to watch closely a while now and I have zero hesitancy today they are one of the developers to keep even closer eyes on They are a relic of Gaming seemingly lost and excruciating difficult to find in the western markets today and they have my full adoration and respect\n\nBaldurs Gate III is in a very small and shrinking category each passing year One of the few games released in recent years I found worth my time and money as it was a full packaged deal that truly captivate me and have me inspired with hope to finally sit down and enjoy where the sky is the limit',
#  'This is a friend for scratch Friends who pass by can pet it and give it a thumbs up\n \n    l\n   x\n    \n   \n  \n \n \n\n\nAstarion rocks',
#  'This game ruined my life',
#  'its cheaper than a heroin addiction',
#  'Once again Larian has proven that CRPGs are truly a masterpiece when it comes to Role Play\nBaldurs Gate 3 is definitely an amazing and a remarkable creation made out of love and passion from its developers\nFrom today Baldurs Gate 3 will stand and rise to the highest pantheon of the best RPGs ever made\n\nAnd let it belet the story of your adventures spread across the Sword Coast of Faerun to the Mainland of Rivellon and become a legend',
#  'There is virtually nothing of value left to be said about Baldurs Gate 3 Its an ambitious title that faithfully captures the lightninginabottle effect that the original had on the industry in 98 while elevating the CRPG genre to greater heights \n\nIn the interests of saying something new I will review its platforming With the recent Patch 5 most of the jumping issues have been fixed though questionable pathfinding still occurs on occasion On the platforming scale of Dark Souls to Super Mario Odyssey Baldurs Gate 3 gets an above average grade',
#  'So yes its amazing just get it if you enjoy Fantasy RPGs\nBut best game ever\nRight so Im not going to sing its praises as everyone else has done this job\nI am going to list how it could have been better and why its maybe not the best game ever Because I can\n1 Level Cap Limitations Yes Ive read the guff online of people defending the limit of 12 but they could easily have allowed you to level up to 1516 without ruining the enjoyment of the game Once you are in act 3 and you hit 12 you still have loads to do Although I found most fights fun at 12 a few more levels would have stopped me having to do a bit of cheese and this was only on balanced mode mind If there are certain overpowered spells remove or nerf them They have basically done this already anyway Dispel Magic anyone\n2 Inventory and Storage system Its such a faff yes Ive seen worse but Ive also seen better One chest for storage in your camp with limited sort options No stacking of the same items so many dagger slots\n3 The Aggro is too random In the Goblin camp you get into it with one group Every Goblin in the world turns on you In a prison you break someone out kill all the guards and you are flirting with their colleagues at the top of the stairs whilst the escaped prisoner is stood next to you As the Goblin Camp is your first experience It restricts experimentation as you try and avoid combat in situations that are valid options as you expect every man and their dog to turn on you\n4 Its too woke Only joking I thought it was fine you snowflakes',
#  'This Game has taken over my life I am thinking about Baldurs gate when I am at work I am thinking about Baldurs gate when I am sleeping I am thinking about Baldurs gate when I am playing Baldurs gate']

# %%
from gensim import corpora
import spacy, re, string
from spacy.tokens import Token

tag_getter = lambda token: token.text in ("h1", "h2", "i", "\n", "\n\n", "\u3000", "\u3000\u3000", '\n\u3000')
Token.set_extension("is_tag", getter=tag_getter, force=True)
nlp = spacy.load('en_core_web_sm')

texts = []
for document in documents:
    text = []
    doc = nlp(document)
    for w in doc:
        if not w.is_stop and not w.is_punct and not w.like_num and not w._.is_tag:
            text.append(w.lemma_.strip())
    texts.append(text)
print(texts)
# Out:
# [['dnd', 'people', 'friend'], ['Karlach'], ['m', 'fancy', 'reviewer', 'gamer', 'consumer', 'like', 'rest', 'kindly', 'request', 'offer', 'minute', 'hear', 'share', 'let', 'start', 'brief', 'Larian', 'Studios', 'blow', 'away', 'context', 'come', 'love', 'divinity', 'game', 'year', 'hype', 'announce', 'successor', 'Balldurs', 'Gate', '', 'II', 'Gamemaster', 'dungeon', '', 'dragon', 'nearly', 'year', 've', 'DnD', 'sphere', 'game', 'rpg', 'beginning', 'Edition', 'young', 'experience', 'system', 'board', 'numerous', 'title', 'accompany
umb': 159, 'x': 160, 'life': 161, 'ruin': 162, 'base': 163, 'bit': 164, 'character': 165, 'combat': 166, 'concept': 167, 'desire': 168, 'differently': 169, 'effort': 170, 'fully': 171, 'fun': 172, 'go': 173, 'invest': 174, 'll': 175, 'meet': 176, 'normal': 177, 'not': 178, 'obvious': 179, 'overall': 180, 'slow': 181, 'spirit': 182, 'story': 183, 'sure': 184, 'taste': 185, 'thing': 186, 'try': 187, 'turn': 188, 'understand': 189, 'virtually': 190, 'way': 191, '2player': 192, 'Act': 193, 'Balduran': 194, 'Bugs': 195, 'Elements': 196, 'Final': 197, 'Gameplay': 198, 'Music': 199, 'River': 200, 'Roleplaying': 201, 'Song': 202, 'Sound': 203, 'Story': 204, 'Super': 205, 'UI': 206, 'Voice': 207, 'act': 208, 'acting': 209, 'action': 210, 'actor': 211, 'affect': 212, 'allow': 213, 'amazing': 214, 'annoy': 215, 'battle': 216, 'betray': 217, 'big': 218, 'blast': 219, 'bug': 220, 'build': 221, 'caliber': 222, 'camp': 223, 'cast': 224, 'chat': 225, 'clichd': 226, 'combine': 227, 'companionsnow': 228, 'comparable': 229, 'compelling': 230, 'complication': 231, 'comprehend': 232, 'concise': 233, 'consequence': 234, 'constantly': 235, 'control': 236, 'coop': 237, 'cutscene': 238, 'debate': 239, 'deep': 240, 'determine': 241, 'dialogue': 242, 'diverse': 243, 'driver': 244, 'easily': 245, 'effortlessly': 246, 'enemy': 247, 'enhance': 248, 'enjoyment': 249, 'etc': 250, 'experiment': 251, 'extremely': 252, 'fantastic': 253, 'favorite': 254, 'flow': 255, 'future': 256, 'gamebreake': 257, 'gameplay': 258, 'gaming': 259, 'get': 260, 'grateful': 261, 'hardfought': 262, 'heck': 263, 'hostgu': 264, 'hurt': 265, 'illusion': 266, 'immediately': 267, 'important': 268, 'inconsistency': 269, 'interaction': 270, 'interesting': 271, 'job': 27 ...

# %% [markdown]
# ## Utilizing Doc2Bow to Convert Doc to Bag of Words

# %%
corpus = [dictionary.doc2bow(text) for text in texts]
corpus
# Out:
# [[(0, 1), (1, 1), (2, 1)],
#  [(3, 1)],
#  [(4, 2),
#   (5, 3),
#   (6, 3),
#   (7, 1),
#   (8, 1),
#   (9, 3),
#   (10, 1),
#   (11, 1),
#   (12, 1),
#   (13, 1),
#   (14, 3),
#   (15, 1),
#   (16, 5),
#   (17, 4),
#   (18, 1),
#   (19, 2),
#   (20, 1),
#   (21, 1),
#   (22, 1),
#   (23, 1),
#   (24, 1),
#   (25, 1),
#   (26, 1),
#   (27, 1),
#   (28, 1),
#   (29, 2),
#   (30, 1),
#   (31, 1),
#   (32, 2),
#   (33, 1),
#   (34, 1),
#   (35, 1),
#   (36, 2),
#   (37, 1),
#   (38, 1),
#   (39, 1),
#   (40, 2),
#   (41, 1),
#   (42, 1),
#   (43, 3),
#   (44, 1),
#   (45, 1),
#   (46, 1),
#   (47, 1),
#   (48, 1),
#   (49, 1),
#   (50, 3),
#   (51, 1),
#   (52, 1),
#   (53, 1),
#   (54, 1),
#   (55, 1),
#   (56, 1),
#   (57, 1),
#   (58, 2),
#   (59, 1),
#   (60, 1),
#   (61, 1),
#   (62, 1),
#   (63, 1),
#   (64, 3),
#   (65, 1),
#   (66, 1),
#   (67, 1),
#   (68, 1),
#   (69, 1),
#   (70, 1),
#   (71, 3),
#   (72, 1),
#   (73, 1),
#   (74, 7),
#   (75, 2),
#   (76, 1),
#   (77, 1),
#   (78, 1),
#   (79, 1),
#   (80, 1),
#   (81, 1),
#   (82, 1),
#   (83, 1),
#   (84, 1),
#   (85, 1),
#   (86, 1),
#   (87, 1),
#   (88, 1),
#   (89, 1),
#   (90, 1),
#   (91, 1),
#   (92, 1),
#   (93, 1),
#   (94, 1),
#   (95, 4),
#   (96, 1),
#   (97, 1),
#   (98, 1),
#   (99, 1),
#   (100, 1),
#   (101, 1),
#   (102, 1),
#   (103, 1),
#   (104, 1),
#   (105, 1),
#   (106, 1),
#   (107, 1),
#   (108, 2),
#   (109, 1),
#   (110, 1),
#   (111, 1),
#   (112, 2),
#   (113, 1),
#   (114, 3),
#   (115, 2),
#   (116, 1),
#   (117, 1),
#   (118, 1),
#   (119, 1),
#   (120, 1),
#   (121, 1),
#   (122, 2),
#   (123, 2),
#   (124, 1),
#   (125, 1),
#   (126, 1),
#   (127, 1),
#   (128, 1),
#   (129, 1),
#   (130, 1),
#   (131, 1),
#   (132, 1),
#   (133, 1),
#   (134, 1),
#   (135, 1),
#   (136, 1),
#   (137, 1),
#   (138, 2),
#   (139, 1),
#   (140, 1),
#   (141, 1),
#   (142, 1),
#   (143, 2),
#   (144, 1),
#   (145, 1),
#   (146, 1),
#   (147, 1),
#   (148, 1),
#   (149, 1),
#   (150, 1),
#   (151, 6),
#   (152, 1)],
#  [(1, 1),
#   (4, 3),
#   (111, 1),
#   (153, 1),
#   (154, 1),
#   (155, 1),
#   (156, 1),
#   (157, 1),
#   (158, 1),
#   (159, 1),
#   (160, 1)],
#  [(74, 1), (161, 1), (162, 1)],
#  [(17, 1),
#   (19, 1),
#   (68, 2),
#   (74, 3),
#   (78, 1),
#   (99, 1),
#   (114, 1),
#   (163, 1),
#   (164, 1),
#   (165, 1),
#   (166, 1),
#   (167, 1),
#   (168, 1),
#   (169, 1),
#   (170, 1),
#   (171, 1),
#   (172, 1),
#   (173, 2),
#   (174, 1),
#   (175, 1),
#   (176, 1),
#   (177, 1),
#   (178, 4),
#   (179, 1),
#   (180, 1),
#   (181, 1),
#   (182, 1),
#   (183, 1),
#   (184, 1),
#   (185, 1),
#   (186, 1),
#   (187, 1),
#   (188, 1),
#   (189, 1),
#   (190, 1),
#   (191, 1)],
#  [(4, 1),
#   (6, 3),
#   (14, 3),
#   (48, 1),
#   (57, 1),
#   (64, 5),
#   (74, 8),
#   (75, 1),
#   (78, 1),
#   (79, 4),
#   (81, 2),
#   (95, 2),
#   (107, 1),
#   (110, 1),
#   (112, 1),
#   (114, 1),
#   (120, 2),
#   (123, 1),
#   (141, 1),
#   (145, 4),
#   (147, 1),
#   (150, 2),
#   (151, 1),
#   (161, 1),
#   (164, 1),
#   (165, 3),
#   (166, 1),
#   (172, 1),
#   (173, 1),
#   (178, 2),
#   (180, 3),
#   (183, 2),
#   (192, 1),
#   (193, 3),
#   (194, 1),
#   (195, 3),
#   (196, 1),
#   (197, 1),
#   (198, 1),
#   (199, 1),
#   (200, 1),
#   (201, 1),
#   (202, 1),
#   (203, 1),
#   (204, 1),
#   (205, 1),
#   (206, 1),
#   (207, 1),
#   (208, 1),
#   (209, 1),
#   (210, 5),
#   (211, 1),
#   (212, 1),
#   (213, 1),
#   (214, 2),
#   (215, 1),
#   (216, 1),
#   (217, 1),
#   (218, 1),
#   (219, 1),
#   (220, 2),
#   (221, 1),
#   (222, 1),
#   (223, 1),
#   (224, 1),
#   (225, 1),
#   (226, 1),
#   (227, 1),
#   (228, 1),
#   (229, 1),
#   (230, 1),
#   (231, 1),
#   (232, 1),
#   (233, 1),
#   (234, 1),
#   (235, 1),
#   (236, 1),
#   (237, 3),
#   (238, 1),
#   (239, 1),
#   (240, 1),
#   (241, 1),
#   (242, 4),
#   (243, 1),
#   (244, 1),
#   (245, 1),
#   (246, 1),
#   (247, 1),
#   (248, 1),
#   (249, 1),
#   (250, 1),
#   (251, 1),
#   (252, 1),
#   (253, 1),
#   (254, 1),
#   (255, 1),
#   (256, 1),
#   (257, 1),
#   (258, 1),
#   (259, 2),
#   (260, 2),
#   (261, 1),
#   (262, 1),
#   (263, 1),
#   (264, 1),
#   (265, 1),
#   (266, 1),
#   (267, 1),
#   (268, 1),
#   (269, 1),
#   (270, 1),
#   (271, 1),
#   (272, 1),
#   (273, 1),
#   (274, 1),
#   (275, 1),
#   (276, 1),
#   (277, 1),
#   (278, 1),
#   (279, 1),
#   (280, 2),
#   (281, 1),
#   (282, 1),
#   (283, 1),
#   (284, 1),
#   (285, 1),
#   (286, 1),
#   (287, 1),
#   (288, 1),
#   (289, 1),
#   (290, 1),
#   (291, 1),
#   (292, 1),
#   (293, 1),
#   (294, 1),
#   (295, 1),
#   (296, 1),
#   (297, 1),
#   (298, 1),
#   (299, 1),
#   (300, 1),
#   (301, 1),
#   (302, 1),
#   (303, 1),
#   (304, 1),
#   (305, 1),
#   (306, 1),
#   (307, 1),
#   (308, 1),
#   (309, 1),
#   (310, 2),
#   (311, 1),
#   (312, 1),
#   (313, 1),
#   (314, 1),
#   (315, 1),
#   (316, 1),
#   (317, 1),
#   (318, 1),
#   (319, 1),
#   (320, 1),
#   (321, 1),
#   (322, 1),
#   (323, 1),
#   (324, 1),
#   (325, 1),
#   (326, 1),
#   (327, 1),
#   (328, 1),
#   (329, 1),
#   (330, 1)],
#  [(4, 1),
#   (50, 1),
#   (74, 1),
#   (78, 2),
#   (95, 1),
#   (114, 1),
#   (123, 3),
#   (125, 1),
#   (141, 2),
#   (147, 1),
#   (163, 1),
#   (178, 3),
#   (183, 3),
#   (186, 1),
#   (193, 3),
#   (198, 1),
#   (211, 1),
#   (214, 1),
#   (223, 2),
#   (224, 1),
#   (238, 1),
#   (260, 1),
#   (284, 1),
#   (306, 1),
#   (315, 2),
#   (327, 1),
#   (331, 1),
#   (332, 1),
#   (333, 1),
#   (334, 1),
#   (335, 1),
#   (336, 1),
#   (337, 1),
#   (338, 1),
#   (339, 1),
#   (340, 1),
#   (341, 1),
#   (342, 1),
#   (343, 1),
#   (344, 1),
#   (345, 2),
#   (346, 1),
#   (347, 1),
#   (348, 2),
#   (349, 1),
#   (350, 3),
#   (351, 1),
#   (352, 1),
#   (353, 1),
#   (354, 1),
#   (355, 1),
#   (356, 1),
#   (357, 1),
#   (358, 1),
#   (359, 1),
#   (360, 1),
#   (361, 1),
#   (362, 1),
#   (363, 1),
#   (364, 1),
#   (365, 1),
#   (366, 1),
#   (367, 1),
#   (368, 1),
#   (369, 1)],
#  [(4, 3),
#   (111, 1),
#   (155, 1),
#   (156, 1),
#   (159, 1),
#   (160, 1),
#   (370, 1),
#   (371, 1),
#   (372, 1),
#   (373, 1)],
#  [(70, 1), (76, 1), (86, 1), (176, 1), (221, 1), (374, 1)],
#  [(1, 1), (50, 1), (178, 1), (252, 1), (375, 1), (376, 1)],
#  [(76, 1), (377, 1)],
#  [(74, 1), (114, 1), (348, 1), (378, 1)],
#  [(2, 1),
#   (3, 1),
#   (43, 1),
#   (50, 1),
#   (71, 1),
#   (74, 9),
#   (94, 2),
#   (95, 3),
#   (98, 1),
#   (114, 2),
#   (123, 1),
#   (125, 1),
#   (141, 4),
#   (150, 1),
#   (164, 1),
#   (171, 1),
#   (173, 1),
#   (176, 1),
#   (178, 9),
#   (179, 2),
#   (184, 1),
#   (186, 2),
#   (187, 1),
#   (191, 1),
#   (193, 1),
#   (220, 2),
#   (236, 1),
#   (242, 1),
#   (247, 1),
#   (252, 1),
#   (278, 2),
#   (280, 3),
#   (282, 2),
#   (287, 1),
#   (315, 1),
#   (316, 1),
#   (318, 1),
#   (319, 1),
#   (337, 2),
#   (338, 1),
#   (340, 1),
#   (341, 2),
#   (344, 1),
#   (347, 2),
#   (350, 1),
#   (351, 1),
#   (362, 1),
#   (367, 1),
#   (379, 1),
#   (380, 1),
#   (381, 1),
#   (382, 1),
#   (383, 1),
#   (384, 1),
#   (385, 1),
#   (386, 1),
#   (387, 1),
#   (388, 1),
#   (389, 1),
#   (390, 1),
#   (391, 3),
#   (392, 1),
#   (393, 1),
#   (394, 1),
#   (395, 1),
#   (396, 1),
#   (397, 1),
#   (398, 2),
#   (399, 1),
#   (400, 1),
#   (401, 1),
#   (402, 1),
#   (403, 1),
#   (404, 1),
#   (405, 2),
#   (406, 1),
#   (407, 1),
#   (408, 1),
#   (409, 1),
#   (410, 1),
#   (411, 1),
#   (412, 1),
#   (413, 1),
#   (414, 1),
#   (415, 1),
#   (416, 3),
#   (417, 4),
#   (418, 2),
#   (419, 3),
#   (420, 1),
#   (421, 1),
#   (422, 1),
#   (423, 3),
#   (424, 1),
#   (425, 1),
#   (426, 1),
#   (427, 1),
#   (428, 1),
#   (429, 2),
#   (430, 1),
#   (431, 5),
#   (432, 1),
#   (433, 1),
#   (434, 1),
#   (435, 1),
#   (436, 1),
#   (437, 1),
#   (438, 2),
#   (439, 3),
#   (440, 1),
#   (441, 1),
#   (442, 1),
#   (443, 2),
#   (444, 1),
#   (445, 1),
#   (446, 2),
#   (447, 1),
#   (448, 1),
#   (449, 1),
#   (450, 1),
#   (451, 2),
#   (452, 2),
#   (453, 1),
#   (454, 1),
#   (455, 1),
#   (456, 1),
#   (457, 1),
#   (458, 1),
#   (459, 1),
#   (460, 2),
#   (461, 1),
#   (462, 1),
#   (463, 1),
#   (464, 2),
#   (465, 3),
#   (466, 1),
#   (467, 1),
#   (468, 2),
#   (469, 2),
#   (470, 1),
#   (471, 1),
#   (472, 1),
#   (473, 1),
#   (474, 1),
#   (475, 1),
#   (476, 1),
#   (477, 1),
#   (478, 1),
#   (479, 2),
#   (480, 1),
#   (481, 1),
#   (482, 2),
#   (483, 1),
#   (484, 1),
#   (485, 1),
#   (486, 3),
#   (487, 1),
#   (488, 2),
#   (489, 1),
#   (490, 1),
#   (491, 1),
#   (492, 3),
#   (493, 1),
#   (494, 1),
#   (495, 1),
#   (496, 1),
#   (497, 1),
#   (498, 2),
#   (499, 1),
#   (500, 1),
#   (501, 1),
#   (502, 1),
#   (503, 4),
#   (504, 2),
#   (505, 1),
#   (506, 1),
#   (507, 1),
#   (508, 1),
#   (509, 1),
#   (510, 1),
#   (511, 1),
#   (512, 1),
#   (513, 1),
#   (514, 1),
#   (515, 1),
#   (516, 1),
#   (517, 1),
#   (518, 1),
#   (519, 2),
#   (520, 1),
#   (521, 2),
#   (522, 1),
#   (523, 1),
#   (524, 2),
#   (525, 1),
#   (526, 1),
#   (527, 2),
#   (528, 1),
#   (529, 1)],
#  [(6, 6),
#   (14, 6),
#   (17, 2),
#   (18, 2),
#   (19, 2),
#   (28, 1),
#   (31, 1),
#   (40, 1),
#   (47, 1),
#   (48, 1),
#   (52, 1),
#   (64, 4),
#   (68, 1),
#   (74, 5),
#   (87, 1),
#   (89, 1),
#   (107, 1),
#   (112, 1),
#   (125, 1),
#   (138, 2),
#   (140, 1),
#   (145, 2),
#   (165, 4),
#   (166, 1),
#   (178, 1),
#   (180, 3),
#   (183, 2),
#   (208, 4),
#   (213, 1),
#   (243, 1),
#   (249, 1),
#   (253, 1),
#   (258, 2),
#   (275, 1),
#   (279, 1),
#   (282, 2),
#   (295, 1),
#   (326, 1),
#   (338, 1),
#   (342, 1),
#   (354, 2),
#   (368, 1),
#   (405, 1),
#   (416, 1),
#   (455, 1),
#   (464, 1),
#   (503, 1),
#   (527, 1),
#   (530, 1),
#   (531, 1),
#   (532, 2),
#   (533, 1),
#   (534, 1),
#   (535, 1),
#   (536, 1),
#   (537, 1),
#   (538, 1),
#   (539, 1),
#   (540, 1),
#   (541, 1),
#   (542, 1),
#   (543, 1),
#   (544, 1),
#   (545, 1),
#   (546, 1),
#   (547, 2),
#   (548, 1),
#   (549, 1),
#   (550, 1),
#   (551, 1),
#   (552, 1),
#   (553, 1),
#   (554, 1),
#   (555, 1),
#   (556, 1),
#   (557, 2),
#   (558, 1),
#   (559, 1),
#   (560, 1),
#   (561, 1),
#   (562, 3),
#   (563, 1),
#   (564, 1),
#   (565, 1),
#   (566, 1),
#   (567, 1),
#   (568, 1),
#   (569, 1),
#   (570, 1),
#   (571, 1),
#   (572, 1),
#   (573, 4),
#   (574, 2),
#   (575, 1),
#   (576, 1),
#   (577, 1),
#   (578, 1),
#   (579, 1),
#   (580, 1),
#   (581, 1),
#   (582, 1),
#   (583, 1),
#   (584, 1),
#   (585, 3),
#   (586, 1),
#   (587, 1),
#   (588, 1),
#   (589, 1),
#   (590, 1),
#   (591, 1),
#   (592, 1),
#   (593, 1),
#   (594, 2),
#   (595, 1),
#   (596, 1),
#   (597, 1),
#   (598, 1),
#   (599, 1),
#   (600, 1),
#   (601, 1),
#   (602, 1),
#   (603, 1),
#   (604, 1),
#   (605, 2),
#   (606, 1),
#   (607, 1),
#   (608, 1),
#   (609, 1),
#   (610, 1),
#   (611, 1),
#   (612, 1),
#   (613, 1),
#   (614, 1),
#   (615, 1),
#   (616, 1),
#   (617, 1),
#   (618, 1),
#   (619, 1),
#   (620, 1)],
#  [(621, 1), (622, 1), (623, 1)],
#  [(6, 2),
#   (14, 2),
#   (17, 1),
#   (43, 1),
#   (48, 1),
#   (52, 1),
#   (78, 1),
#   (94, 1),
#   (98, 1),
#   (114, 1),
#   (125, 1),
#   (143, 1),
#   (145, 1),
#   (183, 1),
#   (214, 1),
#   (277, 1),
#   (291, 1),
#   (382, 1),
#   (609, 1),
#   (624, 1),
#   (625, 1),
#   (626, 1),
#   (627, 1),
#   (628, 1),
#   (629, 1),
#   (630, 1),
#   (631, 1),
#   (632, 1),
#   (633, 1),
#   (634, 1),
#   (635, 1),
#   (636, 1),
#   (637, 1),
#   (638, 1),
#   (639, 1)],
#  [(6, 2),
#   (8, 1),
#   (14, 2),
#   (79, 1),
#   (117, 1),
#   (142, 1),
#   (190, 1),
#   (205, 1),
#   (260, 1),
#   (373, 1),
#   (464, 1),
#   (504, 2),
#   (538, 1),
#   (640, 1),
#   (641, 1),
#   (642, 1),
#   (643, 1),
#   (644, 1),
#   (645, 1),
#   (646, 1),
#   (647, 1),
#   (648, 1),
#   (649, 1),
#   (650, 1),
#   (651, 1),
#   (652, 1),
#   (653, 1),
#   (654, 1),
#   (655, 1),
#   (656, 1),
#   (657, 1),
#   (658, 1),
#   (659, 1),
#   (660, 1),
#   (661, 1),
#   (662, 1),
#   (663, 2),
#   (664, 1),
#   (665, 1),
#   (666, 1),
#   (667, 1)],
#  [(2, 1),
#   (59, 1),
#   (64, 1),
#   (71, 1),
#   (74, 3),
#   (78, 2),
#   (80, 1),
#   (96, 1),
#   (99, 1),
#   (125, 1),
#   (138, 1),
#   (147, 3),
#   (162, 1),
#   (164, 1),
#   (166, 1),
#   (172, 1),
#   (173, 2),
#   (187, 1),
#   (188, 2),
#   (208, 1),
#   (213, 1),
#   (214, 1),
#   (223, 2),
#   (245, 1),
#   (249, 1),
#   (272, 1),
#   (274, 1),
#   (287, 2),
#   (319, 1),
#   (343, 1),
#   (362, 1),
#   (412, 1),
#   (444, 1),
#   (455, 1),
#   (465, 1),
#   (477, 1),
#   (492, 1),
#   (527, 1),
#   (536, 1),
#   (565, 1),
#   (575, 3),
#   (609, 1),
#   (668, 1),
#   (669, 1),
#   (670, 1),
#   (671, 1),
#   (672, 1),
#   (673, 3),
#   (674, 1),
#   (675, 1),
#   (676, 1),
#   (677, 1),
#   (678, 1),
#   (679, 1),
#   (680, 1),
#   (681, 1),
#   (682, 1),
#   (683, 1),
#   (684, 1),
#   (685, 1),
#   (686, 1),
#   (687, 1),
#   (688, 1),
#   (689, 1),
#   (690, 1),
#   (691, 1),
#   (692, 1),
#   (693, 1),
#   (694, 1),
#   (695, 1),
#   (696, 1),
#   (697, 1),
#   (698, 1),
#   (699, 1),
#   (700, 1),
#   (701, 1),
#   (702, 1),
#   (703, 1),
#   (704, 1),
#   (705, 1),
#   (706, 1),
#   (707, 1),
#   (708, 1),
#   (709, 1),
#   (710, 1),
#   (711, 1),
#   (712, 2),
#   (713, 1),
#   (714, 1),
#   (715, 1),
#   (716, 1),
#   (717, 1),
#   (718, 1),
#   (719, 1),
#   (720, 1),
#   (721, 1),
#   (722, 1),
#   (723, 2),
#   (724, 1),
#   (725, 1),
#   (726, 3)],
#  [(6, 4),
#   (76, 4),
#   (114, 1),
#   (161, 1),
#   (315, 1),
#   (319, 3),
#   (369, 1),
#   (727, 1),
#   (728, 1)]]

# %% [markdown]
# ## Utilizing TF-IDF

# %%
from gensim import models
tfidf = models.TfidfModel(corpus)

for document in tfidf[corpus]:
       print(document)
# Out:
# [(0, 0.7449272763999774), (1, 0.4717432314698918), (2, 0.4717432314698918)]
# [(3, 1.0)]
# [(4, 0.060101307189314314), (5, 0.19481514606071504), (6, 0.07829542706418977), (7, 0.06493838202023834), (8, 0.049913055222909765), (9, 0.19481514606071504), (10, 0.06493838202023834), (11, 0.06493838202023834), (12, 0.06493838202023834), (13, 0.06493838202023834), (14, 0.09015196078397147), (15, 0.06493838202023834), (16, 0.3246919101011917), (17, 0.1395509137023247), (18, 0.049913055222909765), (19, 0.08224760497078366), (20, 0.06493838202023834), (21, 0.06493838202023834), (22, 0.06493838202023834), (23, 0.06493838202023834), (24, 0.06493838202023834), (25, 0.06493838202023834), (26, 0.06493838202023834), (27, 0.06493838202023834), (28, 0.049913055222909765), (29, 0.12987676404047668), (30, 0.06493838202023834), (31, 0.049913055222909765), (32, 0.12987676404047668), (33, 0.06493838202023834), (34, 0.06493838202023834), (35, 0.06493838202023834), (36, 0.12987676404047668), (37, 0.06493838202023834), (38, 0.06493838202023834), (39, 0.06493838202023834), (40, 0.09982611044581953), (41, 0.06493838202023834), (42, 0.06493838202023834), (43, 0.1233714074561755), (44, 0.06493838202023834), (45, 0.06493838202023834), (46, 0.06493838
# [(6, 0.44290778461678915), (76, 0.592067011574691), (114, 0.08426940722022584), (161, 0.1744742918276442), (315, 0.14801675289367275), (319, 0.44405025868101833), (369, 0.21176409856711972), (727, 0.27551144424056667), (728, 0.27551144424056667)]

# %% [markdown]
# ## Utilizing Bi-gramming

# %%
import gensim
bigram = gensim.models.Phrases(texts)
texts = [bigram[line] for line in texts]
texts
# Out:
# [['dnd', 'people', 'friend'],
#  ['Karlach'],
#  ['m',
#   'fancy',
#   'reviewer',
#   'gamer',
#   'consumer',
#   'like',
#   'rest',
#   'kindly',
#   'request',
#   'offer',
#   'minute',
#   'hear',
#   'share',
#   'let',
#   'start',
#   'brief',
#   'Larian',
#   'Studios',
#   'blow',
#   'away',
#   'context',
#   'come',
#   'love',
#   'divinity',
#   'game',
#   'year',
#   'hype',
#   'announce',
#   'successor',
#   'Balldurs',
#   'Gate',
#   'II',
#   'Gamemaster',
#   'dungeon',
#   'dragon',
#   'nearly',
#   'year',
#   've',
#   'DnD',
#   'sphere',
#   'game',
#   'rpg',
#   'beginning',
#   'Edition',
#   'young',
#   'experience',
#   'system',
#   'board',
#   'numerous',
#   'title',
#   'accompany',
#   'array',
#   'edition',
#   'publish',
#   'speak',
#   'BG',
#   'III',
#   'Larian',
#   'blow',
#   'away',
#   'expectation',
#   'dd',
#   'experience',
#   'honor',
#   'great',
#   'marker',
#   'DD',
#   'RPG',
#   'CRPG',
#   'history',
#   'find',
#   'dd',
#   'evolve',
#   'year',
#   'Larian',
#   'create',
#   'perfect',
#   'gateway',
#   'Baldurs',
#   'gate',
#   'old',
#   'classic',
#   'fervor',
#   'easy',
#   'accessibility',
#   'edition',
#   'DD',
#   'Baldurs_Gate',
#   'III',
#   'impossible',
#   'perfect',
#   'place',
#   'begin',
#   'play',
#   'DD',
#   'like',
#   'feel',
#   'like',
#   'access',
#   'dd',
#   'group',
#   'like',
#   'play',
#   'BG',
#   'III',
#   'utilize',
#   'good',
#   'part',
#   'game',
#   'system',
#   'highlight',
#   'exemplary',
#   'immersive',
#   'experience',
#   'showcase',
#   'old',
#   'classic',
#   'come',
#   'curate',
#   'heart',
#   'care',
#   'creation',
#   'year',
#   'ago',
#   'rest',
#   'comfortable',
#   'price',
#   'innumerable',
#   'amount',
#   'replayability',
#   'fingertip',
#   'price',
#   'tag',
#   'microtransaction',
#   'subscription',
#   'catch',
#   'BG',
#   'III',
#   'fan',
#   'gamer',
#   'true',
#   'testament',
#   'game',
#   'come',
#   'adore',
#   'respect',
#   'care',
#   'game',
#   'play',
#   'game',
#   'Larian',
#   'Studios',
#   'folk',
#   'choose',
#   'watch',
#   'closely',
#   'hesitancy',
#   'today',
#   'developer',
#   'close',
#   'eye',
#   'relic',
#   'Gaming',
#   'seemingly',
#   'lose',
#   'excruciating',
#   'difficult',
#   'find',
#   'western',
#   'market',
#   'today',
#   'adoration',
#   'respect',
#   'Baldurs_Gate',
#   'III',
#   'small',
#   'shrink',
#   'category',
#   'pass',
#   'year',
#   'game',
#   'release',
#   'recent',
#   'year',
#   'find',
#   'worth',
#   'time',
#   'money',
#   'package',
#   'deal',
#   'truly',
#   'captivate',
#   'inspire',
#   'hope',
#   'finally',
#   'sit',
#   'enjoy',
#   'sky',
#   'limit'],
#  ['friend',
#   'scratch',
#   'Friends',
#   'pass',
#   'pet',
#   'thumb',
#   'l',
#   'x',
#   'Astarion',
#   'rock'],
#  ['game', 'ruin', 'life'],
#  ['try',
#   'good',
#   'spirit',
#   'game',
#   'not',
#   'obvious',
#   'Larian',
#   'Studios',
#   'go',
#   'normal',
#   'effort',
#   'game',
#   'concept',
#   'virtually',
#   'play',
#   'way',
#   'thing',
#   'not',
#   'feel',
#   'invest',
#   'story',
#   'character',
#   'meet',
#   'combat',
#   'bit',
#   'slow',
#   'taste',
#   'fully',
#   'understand',
#   'turn',
#   'base',
#   'game',
#   'overall',
#   'not',
#   'desire',
#   'go',
#   'feel',
#   'differently',
#   'm',
#   'sure',
#   'll',
#   'fun',
#   'not'],
#  ['remind',
#   'proud',
#   'gamer',
#   'Roleplaying',
#   'Elements',
#   'great',
#   'game',
#   'truly',
#   'driver',
#   'seat',
#   'rely',
#   'illusion',
#   'control',
#   'Baldurs_Gate',
#   'manage',
#   'surprise',
#   'matter',
#   'action',
#   'consequence',
#   'order',
#   'action',
#   'determine',
#   'future',
#   'extremely',
#   'enhance',
#   'replayability',
#   'game',
#   'reward',
#   'thoughtful',
#   'action',
#   'truly',
#   'allow',
#   'roleplay',
#   'term',
#   'sadly',
#   'misuse',
#   'modern',
#   'game',
#   'Gameplay',
#   'overall',
#   'gameplay',
#   'super',
#   'rewarding',
#   'constantly',
#   'outcome',
#   'action',
#   'combat',
#   'plus',
#   'great',
#   'build',
#   'variety',
#   'offer',
#   'ton',
#   'fun',
#   'heck',
#   'experiment',
#   'replayability',
#   'Voice',
#   'acting',
#   'dialogue',
#   'simply',
#   'marvelous',
#   'single',
#   'voice',
#   'actor',
#   'amazing',
#   'job',
#   'immediately',
#   'tell',
#   'great',
#   'passion',
#   'line',
#   'dialogue',
#   'flow',
#   'effortlessly',
#   'thank',
#   'amazing',
#   'writing',
#   'Story',
#   'character',
#   'dialogue',
#   'great',
#   'story',
#   'weak',
#   'part',
#   'Baldurs_Gate',
#   'not',
#   'hurt',
#   'overall',
#   'quality',
#   'game',
#   'clichd',
#   'combine',
#   'diverse',
#   'compelling',
#   'cast',
#   'character',
#   'deep',
#   'roleplaying',
#   'mechanic',
#   'story',
#   'overall',
#   'interesting',
#   'worthwhile',
#   'Sound',
#   'Music',
#   'soundtrack',
#   'surely',
#   'stick',
#   'rest',
#   'life',
#   'hear',
#   'River',
#   'time',
#   'character',
#   'creation',
#   'Song',
#   'Balduran',
#   'Act',
#   'favorite',
#   'moment',
#   'gaming',
#   'go',
#   'camp',
#   'hardfought',
#   'battle',
#   'hear',
#   'fantastic',
#   'song',
#   'chat',
#   'companionsnow',
#   'special',
#   'uiux',
#   'pretty',
#   'concise',
#   'UI',
#   'easy',
#   'comprehend',
#   'navigate',
#   'particularly',
#   'important',
#   'game',
#   'like',
#   'think',
#   'worth',
#   'mention',
#   'coop',
#   'experience',
#   'play',
#   'game',
#   '2player',
#   'coop',
#   'get',
#   'to',
#   'easily',
#   'good',
#   'multiplayer',
#   'experience',
#   've',
#   'Super',
#   'smooth',
#   'coop',
#   'interaction',
#   'hostgu',
#   'complication',
#   'like',
#   'game',
#   'blast',
#   'debate',
#   'dialogue',
#   'option',
#   'betray',
#   'truly',
#   'special',
#   'experience',
#   'regard',
#   'Bugs',
#   'game',
#   'big',
#   'naturally',
#   'bug',
#   'act',
#   'perfect',
#   'Act',
#   'annoy',
#   'bit',
#   'bug',
#   'Bugs',
#   'cutscene',
#   'load',
#   'enemy',
#   'take',
#   'action',
#   'visual',
#   'inconsistency',
#   'etc',
#   'Bugs',
#   'Act',
#   'worth',
#   'mention',
#   'gamebreake',
#   'not',
#   'affect',
#   'enjoyment',
#   'Final',
#   'thought',
#   'year',
#   'gaming',
#   'experience',
#   'comparable',
#   'Baldurs_Gate',
#   'truly',
#   'grateful',
#   'get',
#   'experience',
#   'masterpiece',
#   'caliber'],
#  ['not',
#   'finish',
#   'not',
#   'expect',
#   'finish',
#   'time',
#   'soon',
#   'Act',
#   'take',
#   'hour',
#   'Act',
#   'suppose',
#   'hour',
#   'long',
#   'not',
#   'get',
#   'Act',
#   'good',
#   'game',
#   've',
#   'play',
#   'long',
#   'time',
#   'good',
#   'single',
#   'player',
#   'rpg',
#   'Dragonage',
#   'Origins',
#   'support',
#   'multiplayer',
#   'work',
#   'amazing',
#   'cast',
#   'voice',
#   'actor',
#   'core',
#   'companion',
#   'wellwritten',
#   'quest',
#   'explore',
#   'link',
#   'main',
#   'story',
#   'Gameplay',
#   'engage',
#   'save',
#   'freely',
#   'want',
#   'midconversation',
#   'base',
#   'dd',
#   'ruleset',
#   'necessary',
#   'change',
#   'like',
#   'prestidigitation',
#   'spell',
#   'thing',
#   'aware',
#   'Long',
#   'resting',
#   'bunch',
#   'cutscene',
#   'advance',
#   'story',
#   'happen',
#   'camp',
#   'rest',
#   'reason',
#   'suggest',
#   'rest',
#   'camp',
#   'end',
#   'day',
#   'take',
#   'long',
#   'rest',
#   'story',
#   'stuff'],
#  ['leave', 'cat', 'everybody', 'pass', 'pet', 'thumb', 'award', 'l', 'x'],
#  ['honor', 'finally', 'meet', 'Baldur', 'build', 'gate'],
#  ['dd', 'not', 'need', 'friend', 'extremely', 'horny'],
#  ['baldur', 'gate'],
#  ['hour', 'play', 'nice', 'game'],
#  ['People',
#   'complain',
#   'Cyberpunks',
#   'bug',
#   'praise',
#   'game',
#   'month',
#   'later',
#   'bug',
#   'time',
#   'kill',
#   'enemy',
#   'zoom',
#   'corpse',
#   'know',
#   'people',
#   'lust',
#   'goblin',
#   'woman',
#   'not',
#   'want',
#   'goblin',
#   'rear',
#   'fill',
#   'entire',
#   'screen',
#   'second',
#   'time',
#   'kill',
#   'People',
#   'complain',
#   'Mass',
#   'Effect',
#   '3s',
#   'ending',
#   'praise',
#   'game',
#   'ending',
#   'bad',
#   'pick',
#   'control',
#   'destroy',
#   'matter',
#   'scorched',
#   'earth',
#   'slaughter',
#   'person',
#   'meet',
#   'pick',
#   'destroy',
#   'end',
#   'hero',
#   'oh',
#   'way',
#   'take',
#   'entire',
#   'month',
#   'add',
#   'postgame',
#   'aftermath',
#   'party',
#   'halfarse',
#   'solution',
#   'fact',
#   'not',
#   'bother',
#   'add',
#   'end',
#   'game',
#   'slideshow',
#   'like',
#   'Divinity',
#   'Original',
#   'Sin',
#   'People',
#   'complain',
#   'multiple',
#   'rpg',
#   'give',
#   'actual',
#   'choice',
#   'praise',
#   'game',
#   'exact',
#   'thing',
#   'play',
#   'time',
#   'think',
#   'oh',
#   'man',
#   'not',
#   'wait',
#   'play',
#   'choice',
#   'instead',
#   'find',
#   'choice',
#   'not',
#   'matter',
#   'thing',
#   'happen',
#   'anyways',
#   'different',
#   'dialogue',
#   'option',
#   'evil',
#   'route',
#   'happen',
#   'horribly',
#   'writtenand',
#   'not',
#   'change',
#   'long',
#   'run',
#   'obvious',
#   'cut',
#   'content',
#   'week',
#   'launch',
#   'say',
#   'upper',
#   'city',
#   'able',
#   'fully',
#   'explore',
#   'game',
#   'launch',
#   'thank',
#   'upper',
#   'city',
#   'game',
#   'like',
#   'say',
#   'main',
#   'villain',
#   'gatehouse',
#   'lead',
#   'city',
#   'wait',
#   'walk',
#   'anticlimatic',
#   'fight',
#   'Cazadors',
#   'palace',
#   'city',
#   'wall',
#   's',
#   'cut',
#   'content',
#   'like',
#   'Avernus',
#   'thankfully',
#   'rest',
#   'not',
#   'extremely',
#   'obvious',
#   'let',
#   'bring',
#   'elephant',
#   'room',
#   'insanely',
#   'lustful',
#   'companion',
#   'Gale',
#   'come',
#   'hard',
#   'complete',
#   'ahole',
#   'consider',
#   'relationship',
#   'wanna',
#   'romance',
#   'Karlach',
#   's',
#   'go',
#   'try',
#   'push',
#   'poly',
#   'relationship',
#   'entire',
#   'party',
#   'wanna',
#   'hi',
#   'Halsin',
#   'party',
#   's',
#   'love',
#   'ready',
#   'tell',
#   'later',
#   'game',
#   'issue',
#   'modern',
#   'fantasy',
#   'addition',
#   'pack',
#   'cussing',
#   'sexual',
#   'comment',
#   'content',
#   'not',
#   'cool',
#   'edgy',
#   'make',
#   'uncouth',
#   'shatter',
#   'immersion',
#   'mention',
#   'lore',
#   'half',
#   'ignore',
#   'sure',
#   'half',
#   'not',
#   'ignore',
#   'Wizards',
#   'Coast',
#   'official',
#   'dd',
#   'product',
#   'day',
#   's',
#   'massive',
#   'issue',
#   'area',
#   'destroy',
#   'shadow',
#   'curse',
#   'destroy',
#   'spell',
#   'plague',
#   'time',
#   'Shar',
#   'Mystra',
#   'kill',
#   'death',
#   'devastate',
#   'world',
#   'let',
#   'Shar',
#   'transform',
#   'Shadow',
#   'Plane',
#   'Shadowfel',
#   'funnel',
#   'soul',
#   'mention',
#   'Selunes',
#   'divine',
#   'realm',
#   'destroy',
#   'have',
#   'live',
#   'Sune',
#   'bit',
#   'not',
#   'mention',
#   'game',
#   'sex',
#   'book',
#   'Raphs',
#   'lair',
#   'worth',
#   'comment',
#   'game',
#   'heavy',
#   'focus',
#   'Selune',
#   'Shars',
#   'conflict',
#   'course',
#   'lets',
#   'forget',
#   'change',
#   'fantasy',
#   'world',
#   'modern',
#   'particular',
#   'focus',
#   'Act'],
#  ['Baldurs_Gate',
#   'magnificent',
#   'journey',
#   'immerse',
#   'player',
#   'world',
#   'magic',
#   'mystery',
#   'mayhem',
#   'beginning',
#   'game',
#   'capture',
#   'attention',
#   'stunning',
#   'visual',
#   'engage',
#   'storytelling',
#   'intricate',
#   'character',
#   'development',
#   'Larian',
#   'Studios',
#   'truly',
#   'outdo',
#   'create',
#   'experience',
#   'pay',
#   'homage',
#   'beloved',
#   'Baldurs_Gate',
#   'series',
#   'introduce',
#   'fresh',
#   'innovative',
#   'gameplay',
#   'mechanic',
#   'act',
#   'game',
#   'short',
#   'brilliant',
#   'attention',
#   'detail',
#   'environment',
#   'diverse',
#   'array',
#   'character',
#   'complex',
#   'narrative',
#   'choice',
#   'truly',
#   'unforgettable',
#   'experience',
#   'combat',
#   'system',
#   'strategic',
#   'dynamic',
#   'offer',
#   'perfect',
#   'blend',
#   'classic',
#   'RPG',
#   'element',
#   'modern',
#   'gameplay',
#   'character',
#   'creation',
#   'progression',
#   'system',
#   'Baldurs_Gate',
#   'exceptional',
#   'allow',
#   'player',
#   'mold',
#   'character',
#   'unique',
#   'personality',
#   'strength',
#   'weakness',
#   'backstorie',
#   'companion',
#   'encounter',
#   'journey',
#   'wellwritten',
#   'add',
#   'depth',
#   'overall',
#   'narrative',
#   'have',
#   'quirk',
#   'motivation',
#   'Baldurs_Gate',
#   'falter',
#   'final',
#   'act',
#   'journey',
#   'climax',
#   'short',
#   'spectacular',
#   'story',
#   'reach',
#   'pinnacle',
#   'experience',
#   'mar',
#   'noticeable',
#   'lack',
#   'polish',
#   'Quests',
#   'refined',
#   'overall',
#   'level',
#   'detail',
#   'narrative',
#   'environment',
#   'hit',
#   'final',
#   'act',
#   'manage',
#   'deliver',
#   'satisfying',
#   'conclusion',
#   'overarching',
#   'story',
#   'lack',
#   'polish',
#   'undeniable',
#   'plotline',
#   'feel',
#   'rush',
#   'instance',
#   'game',
#   'performance',
#   'dip',
#   'break',
#   'immersive',
#   'experience',
#   'disappointing',
#   'fantastic',
#   'journey',
#   'conclude',
#   'slightly',
#   'tarnished',
#   'finale',
#   'despite',
#   'shortcoming',
#   'Baldurs_Gate',
#   'remain',
#   'mustplay',
#   'rpg',
#   'enthusiast',
#   'majority',
#   'game',
#   'testament',
#   'Larian',
#   'Studios',
#   'dedication',
#   'quality',
#   'final',
#   'act',
#   'unpolished',
#   'not',
#   'diminish',
#   'overall',
#   'enjoyment',
#   'game',
#   'promise',
#   'update',
#   'improvement',
#   's',
#   'hope',
#   'developer',
#   'address',
#   'issue',
#   'ensure',
#   'Baldurs_Gate',
#   'stand',
#   'shine',
#   'example',
#   'modern',
#   'RPG',
#   'excellence'],
#  ['cheap', 'heroin', 'addiction'],
#  ['Larian',
#   'prove',
#   'crpg',
#   'truly',
#   'masterpiece',
#   'come',
#   'Role',
#   'play',
#   'Baldurs_Gate',
#   'definitely',
#   'amazing',
#   'remarkable',
#   'creation',
#   'love',
#   'passion',
#   'developer',
#   'today',
#   'Baldurs_Gate',
#   'stand',
#   'rise',
#   'high',
#   'pantheon',
#   'good',
#   'rpg',
#   'let',
#   'belet',
#   'story',
#   'adventure',
#   'spread',
#   'Sword',
#   'Coast',
#   'Faerun',
#   'Mainland',
#   'Rivellon',
#   'legend'],
#  ['virtually',
#   'value',
#   'leave',
#   'say',
#   'Baldurs_Gate',
#   'ambitious',
#   'title',
#   'faithfully',
#   'capture',
#   'lightninginabottle',
#   'effect',
#   'original',
#   'industry',
#   'elevate',
#   'CRPG',
#   'genre',
#   'great',
#   'height',
#   'interest',
#   'say',
#   'new',
#   'review',
#   'platforming',
#   'recent',
#   'Patch',
#   'jumping',
#   'issue',
#   'fix',
#   'questionable',
#   'pathfinding',
#   'occur',
#   'occasion',
#   'platforming',
#   'scale',
#   'Dark',
#   'Souls',
#   'Super',
#   'Mario',
#   'Odyssey',
#   'Baldurs_Gate',
#   'get',
#   'average',
#   'grade'],
#  ['yes',
#   'amazing',
#   'enjoy',
#   'Fantasy',
#   'rpg',
#   'good',
#   'game',
#   'right',
#   'm',
#   'go',
#   'sing',
#   'praise',
#   'job',
#   'go',
#   'list',
#   'well',
#   'maybe',
#   'good',
#   'game',
#   'level',
#   'Cap',
#   'Limitations',
#   'yes',
#   've',
#   'read',
#   'guff',
#   'online',
#   'people',
#   'defend',
#   'limit',
#   'easily',
#   'allow',
#   'level',
#   'ruin',
#   'enjoyment',
#   'game',
#   'act',
#   'hit',
#   'load',
#   'find',
#   'fight',
#   'fun',
#   'level',
#   'stop',
#   'have',
#   'bit',
#   'cheese',
#   'balanced',
#   'mode',
#   'mind',
#   'certain',
#   'overpower',
#   'spell',
#   'remove',
#   'nerf',
#   'basically',
#   'Dispel',
#   'Magic',
#   'Inventory',
#   'Storage',
#   'system',
#   'faff',
#   'yes',
#   've',
#   'see',
#   'bad',
#   've',
#   'see',
#   'well',
#   'chest',
#   'storage',
#   'camp',
#   'limited',
#   'sort',
#   'option',
#   'stacking',
#   'item',
#   'dagger',
#   'slot',
#   'Aggro',
#   'random',
#   'Goblin',
#   'camp',
#   'group',
#   'Goblin',
#   'world',
#   'turn',
#   'prison',
#   'break',
#   'kill',
#   'guard',
#   'flirt',
#   'colleague',
#   'stair',
#   'whilst',
#   'escaped',
#   'prisoner',
#   'stand',
#   'Goblin',
#   'Camp',
#   'experience',
#   'restrict',
#   'experimentation',
#   'try',
#   'avoid',
#   'combat',
#   'situation',
#   'valid',
#   'option',
#   'expect',
#   'man',
#   'dog',
#   'turn',
#   'woke',
#   'joke',
#   'think',
#   'fine',
#   'snowflake'],
#  ['Game',
#   'take',
#   'life',
#   'think',
#   'Baldurs',
#   'gate',
#   'work',
#   'think',
#   'Baldurs',
#   'gate',
#   'sleep',
#   'think',
#   'Baldurs',
#   'gate',
#   'play',
#   'Baldurs',
#   'gate']]

# %%
dictionary = corpora.Dictionary(texts)
corpus = [dictionary.doc2bow(text) for text in texts]

# %%
# Save generated corpus

corpora.MmCorpus.serialize('data/gensim_corpus.mm', corpus)
